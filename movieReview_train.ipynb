# %% [markdown]
# ### Chargement du dataset

# %%
import pandas as pd

df = pd.read_csv("MovieReview.csv")
display(df.head())
print(df.shape)

df = df.drop('sentiment', axis=1)
# Out:
#   sentiment                                             review
# 0  Positive  With all this stuff going down at the moment w...
# 1  Positive  'The Classic War of the Worlds' by Timothy Hin...
# 2  Negative  The film starts with a manager (Nicholas Bell)...
# 3  Negative  It must be assumed that those who praised this...
# 4  Positive  Superbly trashy and wondrously unpretentious 8...
# (25000, 2)

# %% [markdown]
# ### Nettoyage

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download()
stop_words = stopwords.words('english')

# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)

    # remove stopword
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

df.review = df.review.apply(lambda x :preprocess_sentence(x))
df.head()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
#                                               review
# 0  stuff going moment started listening music wat...
# 1  classic war worlds timothy hines entertaining ...
# 2  film starts manager nicholas bell giving welco...
# 3  must assumed praised film greatest filmed oper...
# 4  superbly trashy wondrously unpretentious explo...

# %% [markdown]
# ### Tokenization

# %%
import tensorflow as tf
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df.review)

# %%
word2idx = tokenizer.word_index
idx2word = tokenizer.index_word
vocab_size = tokenizer.num_words

# %%
print (word2idx)
print (idx2word)
print (vocab_size)
# Out:
# {'movie': 1, 'film': 2, 'one': 3, 'like': 4, 'good': 5, 'time': 6, 'even': 7, 'would': 8, 'story': 9, 'really': 10, 'see': 11, 'well': 12, 'much': 13, 'get': 14, 'bad': 15, 'people': 16, 'also': 17, 'first': 18, 'great': 19, 'made': 20, 'way': 21, 'make': 22, 'could': 23, 'movies': 24, 'think': 25, 'characters': 26, 'character': 27, 'watch': 28, 'two': 29, 'films': 30, 'seen': 31, 'many': 32, 'life': 33, 'plot': 34, 'acting': 35, 'never': 36, 'love': 37, 'little': 38, 'best': 39, 'show': 40, 'know': 41, 'ever': 42, 'man': 43, 'better': 44, 'end': 45, 'still': 46, 'say': 47, 'scene': 48, 'scenes': 49, 'something': 50, 'back': 51, 'real': 52, 'watching': 53, 'though': 54, 'thing': 55, 'old': 56, 'years': 57, 'actors': 58, 'director': 59, 'work': 60, 'another': 61, 'new': 62, 'nothing': 63, 'funny': 64, 'actually': 65, 'makes': 66, 'look': 67, 'find': 68, 'going': 69, 'part': 70, 'every': 71, 'lot': 72, 'world': 73, 'cast': 74, 'quite': 75, 'got': 76, 'want': 77, 'things': 78, 'pretty': 79, 'young': 80, 'seems': 81, 'around': 82, 'horror': 83, 'however': 84, 'fact': 85, 'take': 86, 'big': 87, 'enough': 88, 'long': 89, 'thought': 90, 'series': 91, 'may': 92, 'original': 93, 'give': 94, 'action': 95, 'right': 96, 'without': 97, 'must': 98, 'comedy': 99, 'always': 100, 'times': 101, 'point': 102, 'gets': 103, 'family': 104, 'role': 105, 'come': 106, 'saw': 107, 'almost': 108, 'interesting': 109, 'least': 110, 'done': 111, 'whole': 112, 'music': 113, 'bit': 114, 'guy': 115, 'script': 116, 'far': 117, 'making': 118, 'minutes': 119, 'feel': 120, 'anything': 121, 'last': 122, 'might': 123, 'since': 124, 'performance': 125, 'girl': 126, 'probably': 127, 'woman': 128, 'kind': 129, 'away': 130, 'yet': 131, 'day': 132, 'rather': 133, 'worst': 134, 'fun': 135, 'sure': 136, 'hard': 137, 'anyone': 138, 'played': 139, 'found': 140, 'although': 141, 'especially': 142, 'course': 143, 'believe': 144, 'screen': 145, 'comes': 146, 'looking': 147, 'trying': 148, 'set': 149, 'goes': 150, 'book': 151, 'looks': 152, 'place': 153, 'actor': 154, 'different': 155, 'put': 156, 'money': 157, 'year': 158, 'ending': 159, 'dvd': 160, 'let': 161, 'maybe': 162, 'someone': 163, 'true': 164, 'sense': 165, 'everything': 166, 'reason': 167, 'shows': 168, 'three': 169, 'job': 170, 'worth': 171, 'main': 172, 'together': 173, 'play': 174, 'watched': 175, 'american': 176, 'everyone': 177, 'plays': 178, 'john': 179, 'effects': 180, 'later': 181, 'audience': 182, 'said': 183, 'takes': 184, 'instead': 185, 'house': 186, 'beautiful': 187, 'seem': 188, 'night': 189, 'high': 190, 'version': 191, 'wife': 192, 'left': 193, 'father': 194, 'special': 195, 'seeing': 196, 'half': 197, 'star': 198, 'excellent': 199, 'war': 200, 'shot': 201, 'idea': 202, 'black': 203, 'nice': 204, 'less': 205, 'else': 206, 'mind': 207, 'simply': 208, 'read': 209, 'second': 210, 'fan': 211, 'men': 212, 'death': 213, 'hollywood': 214, 'poor': 215, 'help': 216, 'completely': 217, 'dead': 218, 'used': 219, 'home': 220, 'line': 221, 'short': 222, 'either': 223, 'top': 224, 'given': 225, 'kids': 226, 'budget': 227, 'try': 228, 'classic': 229, 'wrong': 230, 'performances': 231, 'women': 232, 'boring': 233, 'enjoy': 234, 'need': 235, 'use': 236, 'rest': 237, 'low': 238, 'friends': 239, 'production': 240, 'full': 241, 'camera': 242, 'along': 243, 'truly': 244, 'video': 245, 'awful': 246, 'couple': 247, 'tell': 248, 'next': 249, 'remember': 250, 'stupid': 251, 'stars': 252, 'start': 253, 'sex': 254, 'perhaps': 255, 'mean': 256, 'came': 257, 'recommend': 258, 'moments': 259, 'school': 260, 'episode': 261, 'wonderful': 262, 'small': 263, 'face': 264, 'understand': 265, 'terrible': 266, 'playing': 267, 'getting': 268, 'written': 269, 'early': 270, 'name': 271, 'often': 272, 'keep': 273, 'style': 274, 'perfect': 275, 'human': 276, 'person': 277, 'others': 278, 'definitely': 279, 'gives': 280, 'boy': 281, 'lost': 282, 'lines': 283, 'live': 284, 'become': 285, 'dialogue': 286, 'head': 287, 'piece': 288, 'finally': 28 ...
# {1: 'movie', 2: 'film', 3: 'one', 4: 'like', 5: 'good', 6: 'time', 7: 'even', 8: 'would', 9: 'story', 10: 'really', 11: 'see', 12: 'well', 13: 'much', 14: 'get', 15: 'bad', 16: 'people', 17: 'also', 18: 'first', 19: 'great', 20: 'made', 21: 'way', 22: 'make', 23: 'could', 24: 'movies', 25: 'think', 26: 'characters', 27: 'character', 28: 'watch', 29: 'two', 30: 'films', 31: 'seen', 32: 'many', 33: 'life', 34: 'plot', 35: 'acting', 36: 'never', 37: 'love', 38: 'little', 39: 'best', 40: 'show', 41: 'know', 42: 'ever', 43: 'man', 44: 'better', 45: 'end', 46: 'still', 47: 'say', 48: 'scene', 49: 'scenes', 50: 'something', 51: 'back', 52: 'real', 53: 'watching', 54: 'though', 55: 'thing', 56: 'old', 57: 'years', 58: 'actors', 59: 'director', 60: 'work', 61: 'another', 62: 'new', 63: 'nothing', 64: 'funny', 65: 'actually', 66: 'makes', 67: 'look', 68: 'find', 69: 'going', 70: 'part', 71: 'every', 72: 'lot', 73: 'world', 74: 'cast', 75: 'quite', 76: 'got', 77: 'want', 78: 'things', 79: 'pretty', 80: 'young', 81: 'seems', 82: 'around', 83: 'horror', 84: 'however', 85: 'fact', 86: 'take', 87: 'big', 88: 'enough', 89: 'long', 90: 'thought', 91: 'series', 92: 'may', 93: 'original', 94: 'give', 95: 'action', 96: 'right', 97: 'without', 98: 'must', 99: 'comedy', 100: 'always', 101: 'times', 102: 'point', 103: 'gets', 104: 'family', 105: 'role', 106: 'come', 107: 'saw', 108: 'almost', 109: 'interesting', 110: 'least', 111: 'done', 112: 'whole', 113: 'music', 114: 'bit', 115: 'guy', 116: 'script', 117: 'far', 118: 'making', 119: 'minutes', 120: 'feel', 121: 'anything', 122: 'last', 123: 'might', 124: 'since', 125: 'performance', 126: 'girl', 127: 'probably', 128: 'woman', 129: 'kind', 130: 'away', 131: 'yet', 132: 'day', 133: 'rather', 134: 'worst', 135: 'fun', 136: 'sure', 137: 'hard', 138: 'anyone', 139: 'played', 140: 'found', 141: 'although', 142: 'especially', 143: 'course', 144: 'believe', 145: 'screen', 146: 'comes', 147: 'looking', 148: 'trying', 149: 'set', 150: 'goes', 151: 'book', 152: 'looks', 153: 'place', 154: 'actor', 155: 'different', 156: 'put', 157: 'money', 158: 'year', 159: 'ending', 160: 'dvd', 161: 'let', 162: 'maybe', 163: 'someone', 164: 'true', 165: 'sense', 166: 'everything', 167: 'reason', 168: 'shows', 169: 'three', 170: 'job', 171: 'worth', 172: 'main', 173: 'together', 174: 'play', 175: 'watched', 176: 'american', 177: 'everyone', 178: 'plays', 179: 'john', 180: 'effects', 181: 'later', 182: 'audience', 183: 'said', 184: 'takes', 185: 'instead', 186: 'house', 187: 'beautiful', 188: 'seem', 189: 'night', 190: 'high', 191: 'version', 192: 'wife', 193: 'left', 194: 'father', 195: 'special', 196: 'seeing', 197: 'half', 198: 'star', 199: 'excellent', 200: 'war', 201: 'shot', 202: 'idea', 203: 'black', 204: 'nice', 205: 'less', 206: 'else', 207: 'mind', 208: 'simply', 209: 'read', 210: 'second', 211: 'fan', 212: 'men', 213: 'death', 214: 'hollywood', 215: 'poor', 216: 'help', 217: 'completely', 218: 'dead', 219: 'used', 220: 'home', 221: 'line', 222: 'short', 223: 'either', 224: 'top', 225: 'given', 226: 'kids', 227: 'budget', 228: 'try', 229: 'classic', 230: 'wrong', 231: 'performances', 232: 'women', 233: 'boring', 234: 'enjoy', 235: 'need', 236: 'use', 237: 'rest', 238: 'low', 239: 'friends', 240: 'production', 241: 'full', 242: 'camera', 243: 'along', 244: 'truly', 245: 'video', 246: 'awful', 247: 'couple', 248: 'tell', 249: 'next', 250: 'remember', 251: 'stupid', 252: 'stars', 253: 'start', 254: 'sex', 255: 'perhaps', 256: 'mean', 257: 'came', 258: 'recommend', 259: 'moments', 260: 'school', 261: 'episode', 262: 'wonderful', 263: 'small', 264: 'face', 265: 'understand', 266: 'terrible', 267: 'playing', 268: 'getting', 269: 'written', 270: 'early', 271: 'name', 272: 'often', 273: 'keep', 274: 'style', 275: 'perfect', 276: 'human', 277: 'person', 278: 'others', 279: 'definitely', 280: 'gives', 281: 'boy', 282: 'lost', 283: 'lines', 284: 'live', 285: 'become', 286: 'dialogue', 287: 'head', 288: 'piece', 289: 'finally ...
# 10000

# %% [markdown]
# ### Modélisation

# %%
import numpy as np


def sentenceToData(tokens, WINDOW_SIZE):
    window = np.concatenate((np.arange(-WINDOW_SIZE,0),np.arange(1,WINDOW_SIZE+1)))
    X,Y=([],[])
    for word_index, word in enumerate(tokens) :
        if ((word_index - WINDOW_SIZE >= 0) and (word_index + WINDOW_SIZE <= len(tokens) - 1)) :
            X.append(word)
            Y.append([tokens[word_index-i] for i in window])
    return X, Y


WINDOW_SIZE = 5

X, Y = ([], [])
for review in df.review:
    for sentence in review.split("."):
        word_list = tokenizer.texts_to_sequences([sentence])[0]
        if len(word_list) >= WINDOW_SIZE:
            Y1, X1 = sentenceToData(word_list, WINDOW_SIZE//2)
            X.extend(X1)
            Y.extend(Y1)
    
X = np.array(X).astype(int)
y = np.array(Y).astype(int).reshape([-1,1])

# %%
print(X[0])
print (y[0])
print (df['review'])
print ([idx2word[tok] for tok in X[0]])
print (idx2word[414])
# Out:
# [2424  499   69  398]
# [414]
# 0        stuff going moment started listening music wat...
# 1        classic war worlds timothy hines entertaining ...
# 2        film starts manager nicholas bell giving welco...
# 3        must assumed praised film greatest filmed oper...
# 4        superbly trashy wondrously unpretentious explo...
#                                ...
# 24995    seems like consideration gone imdb reviews fil...
# 24996    believe made film . completely unnecessary . f...
# 24997    guy loser . get girls needs build picked stron...
# 24998    minute documentary bunuel made early one spain...
# 24999    saw movie child broke heart ! story unfinished...
# Name: review, Length: 25000, dtype: object
# ['listening', 'started', 'going', 'stuff']
# moment

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D

embedding_dim = 300
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(GlobalAveragePooling1D())
model.add(Dense(vocab_size, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, y, batch_size = 128, epochs=5)
# Out:
# Epoch 1/5
# 12163/12163 ━━━━━━━━━━━━━━━━━━━━ 586s 48ms/step - accuracy: 0.0354 - loss: 7.5599
# Epoch 2/5
# 12163/12163 ━━━━━━━━━━━━━━━━━━━━ 590s 49ms/step - accuracy: 0.0604 - loss: 6.9041
# Epoch 3/5
# 12163/12163 ━━━━━━━━━━━━━━━━━━━━ 604s 50ms/step - accuracy: 0.0768 - loss: 6.4861
# Epoch 4/5
# 12163/12163 ━━━━━━━━━━━━━━━━━━━━ 633s 52ms/step - accuracy: 0.0899 - loss: 6.1628
# Epoch 5/5
# 12163/12163 ━━━━━━━━━━━━━━━━━━━━ 649s 53ms/step - accuracy: 0.1014 - loss: 5.8980

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 4, 300)         │     3,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 300)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10000)          │     3,010,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,030,002 (68.78 MB)
#  Trainable params: 6,010,000 (22.93 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 12,020,002 (45.85 MB)

# %% [markdown]
# ### Sauvegarde

# %%
model.save("word2vec.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
